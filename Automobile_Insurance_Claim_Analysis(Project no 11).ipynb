# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Automobile_Insurance_claim.csv")
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
df.tail()
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
#      Education Effective To Date EmploymentStatus  ...  \
# 9129  Bachelor           2/10/11         Employed  ...
# 9130   College           2/12/11         Employed  ...
# 9131  Bachelor            2/6/11       Unemployed  ...
# 9132   College            2/3/11         Employed  ...
# 9133   College           2/14/11       Unemployed  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 9129                            89                          0
# ...

# %%
df.shape
# Out:
# (9134, 26)

# %%
df.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
#Checking the unique values and their count
for i in df.columns:
    print(df[i].value_counts())
    print()
# Out:
# VZ16820    1
# SD61306    1
# AQ70385    1
# WA25797    1
# QZ17137    1
#           ..
# GY99495    1
# GR26937    1
# ED61615    1
# CC85895    1
# ER66372    1
# Name: Customer, Length: 9134, dtype: int64
#
# US    9134
# Name: Country, dtype: int64
#
# MO    3150
# IA    2601
# NE    1703
# OK     882
# KS     798
# Name: State Code, dtype: int64
#
# Missouri    3150
# Iowa        2601
# Nebraska    1703
# Oklahoma     882
# Kansas       798
# Name: State, dtype: int64
#
# 472.686933     6
# 272.535640     6
# 575.744226     6
# 592.672938     6
# 1216.874492    6
#               ..
# 919.868511     1
# 287.543239     1
# 623.430592     1
# 910.389970     1
# 816.951398     1
# Name: Claim Amount, Length: 8041, dtype: int64
#
# No     7826
# Yes    1308
# Name: Response, dtype: int64
#
# Basic       5568
# Extended    2742
# Premium      824
# Name: Coverage, dtype: int64
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# ...

# %%
df.groupby(['State','Education','Coverage']).mean()
# Out:
#                                         Claim Amount        Income  \
# State    Education            Coverage
# Iowa     Bachelor             Basic       722.116897  37409.434156
#                               Extended    769.917926  35895.129032
#                               Premium    1176.521668  44923.657534
#          College              Basic       715.000563  38708.608051
#                               Extended    926.407436  36523.030043
# ...                                              ...           ...
# Oklahoma High School or Below Extended    932.667894  36079.284211
#                               Premium    1047.409741  36142.642857
#          Master               Basic       703.643566  49789.211538
#                               Extended    925.902858  41197.842105
#                               Premium     644.452009  57083.400000
#
#                                         Monthly Premium Auto  \
# State    Education            Coverage
# ...

# %%
df.groupby(['State','Vehicle Class','Vehicle Size']).mean()
# Out:
#                                      Claim Amount        Income  \
# State    Vehicle Class Vehicle Size
# Iowa     Four-Door Car Large           685.508576  34997.623188
#                        Medsize         677.239780  39079.844170
#                        Small           690.658496  34575.624031
#          Luxury Car    Large          1346.577652  54367.750000
#                        Medsize        1475.393127  36402.925926
# ...                                           ...           ...
# Oklahoma Sports Car    Medsize        1071.165657  34603.897436
#                        Small           741.380093  24713.600000
#          Two-Door Car  Large           552.074643  50290.347826
#                        Medsize         700.013928  39349.875912
#                        Small           579.157136  34885.818182
#
#                                      Monthly Premium Auto  \
# State    Vehicle Class Vehicle Size
# Iowa     Four-Door Car Large                    78.942029
# ...

# %%
Missouri=df[(df['State']=='Missouri')]
Missouri.head()
# Out:
#    Customer Country State Code     State  Claim Amount Response Coverage  \
# 3   WW63253      US         MO  Missouri    764.586183       No    Basic
# 10  SX51350      US         MO  Missouri    473.899202       No    Basic
# 11  VQ65197      US         MO  Missouri    819.719708       No    Basic
# 12  DP39365      US         MO  Missouri    879.879700       No  Premium
# 14  IL66569      US         MO  Missouri    538.443166       No    Basic
#
#    Education Effective To Date EmploymentStatus  ...  \
# 3   Bachelor           1/20/11       Unemployed  ...
# 10   College           2/21/11       Unemployed  ...
# 11   College            1/6/11       Unemployed  ...
# 12    Master            2/6/11         Employed  ...
# 14   College           1/18/11         Employed  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 3                             65                          0
# 10                             5                          0
# ...

# %%
Missouri.shape
# Out:
# (3150, 26)

# %%
Missouri['Response'].value_counts()
# Out:
# No     2694
# Yes     456
# Name: Response, dtype: int64

# %%
Missouri['Coverage'].value_counts()
# Out:
# Basic       1916
# Extended     952
# Premium      282
# Name: Coverage, dtype: int64

# %%
Missouri['Education'].value_counts()
# Out:
# Bachelor                971
# College                 948
# High School or Below    877
# Master                  254
# Doctor                  100
# Name: Education, dtype: int64

# %%
Missouri['EmploymentStatus'].value_counts()
# Out:
# Employed         1957
# Unemployed        804
# Medical Leave     151
# Disabled          131
# Retired           107
# Name: EmploymentStatus, dtype: int64

# %%
df.plot.box()
plt.xticks(rotation=90)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]), <a list of 8 Text xticklabel objects>)

# %%
sns.catplot(x="State",y="Claim Amount",data=df)

# %%
sns.catplot(x="State",y="Claim Amount",hue="Response",data=df,kind="bar")

# %%
sns.catplot(x="State",y="Claim Amount",hue="Coverage",data=df,kind="bar")

# %%
plt.figure(figsize=(12,10))
sns.catplot(x="State",y="Claim Amount",hue="Education",data=df,kind="bar")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.catplot(x="State",y="Total Claim Amount",hue="EmploymentStatus",data=df,kind="bar")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.catplot(x="State",y="Claim Amount",hue="Number of Open Complaints",data=df,kind="bar")
plt.show()

# %%
sns.catplot(x="State",y="Total Claim Amount",hue="Gender",data=df,kind="bar")
plt.show()

# %%
sns.regplot(x="Income",y="Total Claim Amount",data=df)

# %%
sns.scatterplot(x="Income",y="Claim Amount",data=df)

# %%
sns.catplot(x="Policy Type",y="Claim Amount",hue="Gender",data=df,kind="bar")
plt.show()

# %%
sns.catplot(x="Policy Type",y="Claim Amount",hue="Vehicle Size",data=df,kind="bar")
plt.show()

# %%
sns.catplot(x="Policy Type",y="Claim Amount",hue="Claim Reason",data=df,kind="bar")
plt.show()

# %%
sns.catplot(x="Policy Type",y="Claim Amount",hue="Policy",data=df,kind="bar")
plt.show()

# %%
sns.catplot(x="Policy Type",y="Claim Amount",hue="Marital Status",data=df,kind="bar")
plt.show()

# %%
sns.catplot(x="Policy Type",y="Claim Amount",hue="Location Code",data=df,kind="bar")
plt.show()

# %%
sns.catplot(x="Policy Type",y="Claim Amount",hue="Sales Channel",data=df,kind="bar")
plt.show()

# %% [markdown]
# Data Cleaning And Imputation

# %%
# lets drop some columns
df.drop(['Customer','Country','State Code','Effective To Date'],axis=1,inplace=True)
df.head()
# Out:
#       State  Claim Amount Response  Coverage Education EmploymentStatus  \
# 0    Kansas    276.351928       No     Basic  Bachelor         Employed
# 1  Nebraska    697.953590       No  Extended  Bachelor       Unemployed
# 2  Oklahoma   1288.743165       No   Premium  Bachelor         Employed
# 3  Missouri    764.586183       No     Basic  Bachelor       Unemployed
# 4    Kansas    281.369258       No     Basic  Bachelor         Employed
#
#   Gender  Income Location Code Marital Status  ...  \
# 0      F   56274      Suburban        Married  ...
# 1      F       0      Suburban         Single  ...
# 2      F   48767      Suburban        Married  ...
# 3      M       0      Suburban        Married  ...
# 4      M   43836         Rural         Single  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# ...

# %%
df['Claim']=df['Claim Amount']
df.drop('Claim Amount',axis=1,inplace=True)

# %%
# Income should not be "0", so here  I use mean in place of 0 value
df['Income'].mean()
# Out:
# 37657.38000875848

# %%
sns.boxplot(df['Income'])

# %%
df['Income'].median()
# Out:
# 33889.5

# %%
df['Income'].fillna(df['Income'].mean(),inplace=True)

# %%
df.head()
# Out:
#       State Response  Coverage Education EmploymentStatus Gender  Income  \
# 0    Kansas       No     Basic  Bachelor         Employed      F   56274
# 1  Nebraska       No  Extended  Bachelor       Unemployed      F       0
# 2  Oklahoma       No   Premium  Bachelor         Employed      F   48767
# 3  Missouri       No     Basic  Bachelor       Unemployed      M       0
# 4    Kansas       No     Basic  Bachelor         Employed      M   43836
#
#   Location Code Marital Status  Monthly Premium Auto  ...  \
# 0      Suburban        Married                    69  ...
# 1      Suburban         Single                    94  ...
# 2      Suburban        Married                   108  ...
# 3      Suburban        Married                   106  ...
# 4         Rural         Single                    73  ...
#
#    Number of Open Complaints  Number of Policies     Policy Type  \
# 0                          0                   1  Corporate Auto
# ...

# %%
df.describe()
# Out:
#              Income  Monthly Premium Auto  Months Since Last Claim  \
# count   9134.000000           9134.000000              9134.000000
# mean   37657.380009             93.219291                15.097000
# std    30379.904734             34.407967                10.073257
# min        0.000000             61.000000                 0.000000
# 25%        0.000000             68.000000                 6.000000
# 50%    33889.500000             83.000000                14.000000
# 75%    62320.000000            109.000000                23.000000
# max    99981.000000            298.000000                35.000000
#
#        Months Since Policy Inception  Number of Open Complaints  \
# count                    9134.000000                9134.000000
# mean                       48.064594                   0.384388
# std                        27.905991                   0.910384
# min                         0.000000                   0.000000
# ...

# %% [markdown]
# Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df.columns:
    if df[col].dtypes=='object':
        df[col]=le.fit_transform(df[col])

# %%
df.dtypes
# Out:
# State                              int32
# Response                           int32
# Coverage                           int32
# Education                          int32
# EmploymentStatus                   int32
# Gender                             int32
# Income                             int64
# Location Code                      int32
# Marital Status                     int32
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int32
# Policy                             int32
# Claim Reason                       int32
# Sales Channel                      int32
# Total Claim Amount               float64
# Vehicle Class                      int32
# Vehicle Size                       int32
# Claim                            float64
# dtype: object

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                   State  Response  Coverage  Education  \
# State                          1.000000 -0.001732  0.007558   0.004256
# Response                      -0.001732  1.000000  0.000642   0.000285
# Coverage                       0.007558  0.000642  1.000000   0.021573
# Education                      0.004256  0.000285  0.021573   1.000000
# EmploymentStatus              -0.004054 -0.016703  0.003239  -0.025271
# Gender                         0.000545  0.004396 -0.014448   0.002206
# Income                         0.002682  0.011932 -0.010646   0.018709
# Location Code                  0.001382  0.001729 -0.020176  -0.011533
# Marital Status                -0.008975 -0.094843  0.002956   0.005675
# Monthly Premium Auto          -0.005549  0.010966  0.458997   0.023952
# Months Since Last Claim        0.009249 -0.016597  0.016925   0.003021
# Months Since Policy Inception -0.004459  0.002952  0.010658   0.004140
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)

# %%
# removing outliers
from scipy.stats import zscore
print(df.shape)
z=np.abs(zscore(df))
df_new=df[(z<3).all(axis=1)]
print(df_new.shape)
# Out:
# (9134, 22)
# (8470, 22)

# %% [raw]
# 674 rows are deleted as an outliers

# %%
# Splitting Data into X and Y
x=df_new.iloc[:,:-1]
print(x.shape)
y=pd.DataFrame(df_new.iloc[:,-1])
print(y.shape)
# Out:
# (8470, 21)
# (8470, 1)

# %%
#To Check Skewness
x.skew()
# Out:
# State                            0.019194
# Response                         2.030625
# Coverage                         1.080580
# Education                        0.337866
# EmploymentStatus                 0.844023
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Marital Status                  -0.099961
# Monthly Premium Auto             1.330466
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        2.574570
# Number of Policies               1.226531
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.725402
# Sales Channel                    0.503296
# Total Claim Amount               0.709643
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
#using sqrt function to reduce skewness
for i in x.columns:
    if x.skew()[i]>0.55:
        x[i]=np.sqrt(x[i])

# %%
x.skew()
# Out:
# State                            0.019194
# Response                         2.030625
# Coverage                         0.637514
# Education                        0.337866
# EmploymentStatus                 0.096940
# Gender                           0.044411
# Income                           0.282827
# Location Code                    0.012291
# Marital Status                  -0.099961
# Monthly Premium Auto             0.973258
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        1.871949
# Number of Policies               0.834717
# Policy Type                     -0.459843
# Policy                          -0.415012
# Claim Reason                     0.024930
# Sales Channel                    0.503296
# Total Claim Amount              -0.336015
# Vehicle Class                    0.403978
# Vehicle Size                     0.071461
# dtype: float64

# %%
#as the skewness needs to be reduced again, we use log function to reduce
for i in x.columns:
    if x.skew()[i]>0.55:
        x[i]=np.log1p(x[i])

# %%
x.head()
# Out:
#    State  Response  Coverage  Education  EmploymentStatus  Gender  Income  \
# 0      1       0.0  0.000000          0               1.0       0   56274
# 1      3       0.0  0.693147          0               2.0       0       0
# 2      4       0.0  0.881374          0               1.0       0   48767
# 3      2       0.0  0.000000          0               2.0       1       0
# 4      1       0.0  0.000000          0               1.0       1   43836
#
#    Location Code  Marital Status  Monthly Premium Auto  ...  \
# 0              1               1              2.230726  ...
# 1              1               2              2.369810  ...
# 2              1               1              2.432938  ...
# 3              1               1              2.424416  ...
# 4              0               2              2.255913  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                        0.0
# ...

# %%
#Applying Standardscaler for scaling data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)
x=pd.DataFrame(x)
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.551121 -0.409822 -0.771876 -1.120269 -0.487255 -0.978045  0.604143
# 1  0.974119 -0.409822  1.156837 -1.120269  1.477330 -0.978045 -1.244638
# 2  1.736738 -0.409822  1.680586 -1.120269 -0.487255 -0.978045  0.357514
# 3  0.211499 -0.409822 -0.771876 -1.120269  1.477330  1.022448 -1.244638
# 4 -0.551121 -0.409822 -0.771876 -1.120269 -0.487255  1.022448  0.195515
#
#          7         8         9   ...        11        12        13        14  \
# 0  0.037243 -0.186015 -0.804384  ... -1.535241 -0.472585 -1.032614 -1.717870
# 1  0.037243  1.394274  0.348142  ... -0.208285 -0.472585  1.788314  0.372999
# 2  0.037243 -0.186015  0.871258  ... -0.351739 -0.472585 -0.214860  0.372999
# 3  0.037243 -0.186015  0.800639  ...  0.616580 -0.472585  1.575904 -1.717870
# 4 -1.597204  1.394274 -0.595673  ... -0.136557 -0.472585 -1.032614  0.372999
#
#          15        16        17        18        19        20
# ...

# %% [markdown]
# # Train-Test-Split

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def maxr2_score(regr,x,y):
    max_r2_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2score=r2_score(y_test,y_pred)
        print("The r2 score at r state", r_state, "is", r2score )
        if r2score>max_r2_score:
            max_r2_score=r2score
            final_r_state=r_state
    print("The max r2 score", max_r2_score, "is achieved at r_state", final_r_state)
    return final_r_state

# %%
# lets use Linear Regression and check max r2 score corresponding to different random states
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# The r2 score at r state 42 is 0.14136882490068736
# The r2 score at r state 43 is 0.15346342794024326
# The r2 score at r state 44 is 0.11190616576231982
# The r2 score at r state 45 is 0.1506229280869077
# The r2 score at r state 46 is 0.12891953256989486
# The r2 score at r state 47 is 0.1271760657190164
# The r2 score at r state 48 is 0.14303426064098168
# The r2 score at r state 49 is 0.12535408340794074
# The r2 score at r state 50 is 0.14108205704763466
# The r2 score at r state 51 is 0.1041152461701702
# The r2 score at r state 52 is 0.131221982371184
# The r2 score at r state 53 is 0.12831456463035895
# The r2 score at r state 54 is 0.12051700333619364
# The r2 score at r state 55 is 0.10986376795501296
# The r2 score at r state 56 is 0.13048697155419997
# The r2 score at r state 57 is 0.1147471247830747
# The r2 score at r state 58 is 0.1372127137471294
# The r2 score at r state 59 is 0.14527009835743077
# The r2 score at r state 60 is 0.12803825529860002
# ...

# %%
#Lets finalise the train and test data
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=73,test_size=0.20)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6776, 21)
# (6776, 1)
# (1694, 21)
# (1694, 1)

# %%
# lets use GridSearchCV to find optimalvalue of n-neighbors for KNN Model
from sklearn.model_selection import GridSearchCV
neighbors={"n_neighbors":range(1,30)}
KNR=KNeighborsRegressor()
gknr=GridSearchCV(KNR,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 16}

# %%
# Lets use KNR and check max r2 score corresponding to different random states
KNR=KNeighborsRegressor(n_neighbors=16)
r_state=maxr2_score(KNR,x,y)
# Out:
# The r2 score at r state 42 is 0.15176376242799827
# The r2 score at r state 43 is 0.154401964481659
# The r2 score at r state 44 is 0.17623819968980825
# The r2 score at r state 45 is 0.1905546980270404
# The r2 score at r state 46 is 0.13100855287444013
# The r2 score at r state 47 is 0.16643163735537592
# The r2 score at r state 48 is 0.16672867833540794
# The r2 score at r state 49 is 0.16731653013681258
# The r2 score at r state 50 is 0.14742763404355874
# The r2 score at r state 51 is 0.14313016494820163
# The r2 score at r state 52 is 0.17856138931258703
# The r2 score at r state 53 is 0.16577538006966475
# The r2 score at r state 54 is 0.14808330386467328
# The r2 score at r state 55 is 0.16877540607188846
# The r2 score at r state 56 is 0.16289566175436632
# The r2 score at r state 57 is 0.14359279804396563
# The r2 score at r state 58 is 0.17610088873485064
# The r2 score at r state 59 is 0.18408343857254184
# The r2 score at r state 60 is 0.16058042640986547
# ...

# %%
# lets use GridSearchCV to find optimalvalue of kernel for SVR Model
parameters={"kernel":["linear",'poly','rbf'],"C":[1,10]}
sv=SVR()
gsv=GridSearchCV(sv,parameters,cv=10)
gsv.fit(x,y)
gsv.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
# Lets use SVR and check max r2 score corresponding to different random states
sv=SVR(kernel="rbf",C=10)
r_state=maxr2_score(sv,x,y)
# Out:
# The r2 score at r state 42 is 0.0406797260342594
# The r2 score at r state 43 is 0.046319939080713635
# The r2 score at r state 44 is -0.012441006187796644
# The r2 score at r state 45 is 0.05262593145782679
# The r2 score at r state 46 is 0.02581720391412423
# The r2 score at r state 47 is 0.04301871175252314
# The r2 score at r state 48 is 0.04534408792752953
# The r2 score at r state 49 is 0.014621443785776456
# The r2 score at r state 50 is 0.03627095004428904
# The r2 score at r state 51 is -4.2326859783337056e-05
# The r2 score at r state 52 is 0.013575770689709499
# The r2 score at r state 53 is 0.028918496603608457
# The r2 score at r state 54 is 0.027697290991007484
# The r2 score at r state 55 is -0.004148155681410248
# The r2 score at r state 56 is 0.02243377225050569
# The r2 score at r state 57 is -0.0021776427319506464
# The r2 score at r state 58 is 0.03873815178648832
# The r2 score at r state 59 is 0.04064189718171696
# ...

# %%
# lets check the mean r2 score , standard deviation of LinearRegressor, KNR ,SVR
print("score for LinearRegression :",cross_val_score(lreg,x,y,cv=10,scoring="r2"))
print("Mean r2 score for LinearRegression :",cross_val_score(lreg,x,y,cv=10,scoring="r2").mean())
print("Standard Deviation in r2 score for LinearRegression :",cross_val_score(lreg,x,y,cv=10,scoring="r2").std())  
print("")
print("score for KNR :",cross_val_score(KNR,x,y,cv=10,scoring="r2"))
print("Mean r2 score for KNR :",cross_val_score(KNR,x,y,cv=10,scoring="r2").mean())
print("Standard Deviation in r2 score for KNR :",cross_val_score(KNR,x,y,cv=10,scoring="r2").std())  
print("")
print("score for SVR :",cross_val_score(sv,x,y,cv=10,scoring="r2"))
print("Mean r2 score for SVR :",cross_val_score(sv,x,y,cv=10,scoring="r2").mean())
print("Standard Deviation in r2 score for SVR :",cross_val_score(sv,x,y,cv=10,scoring="r2").std())  
print("")
# Out:
# score for LinearRegression : [0.11377371 0.10580342 0.12836428 0.11300192 0.18397098 0.10725161
#  0.15820357 0.13646133 0.09004917 0.14362051]
# Mean r2 score for LinearRegression : 0.12805004940444184
# Standard Deviation in r2 score for LinearRegression : 0.026742264546230864
#
# score for KNR : [0.18482361 0.12657244 0.19544545 0.15424681 0.17017185 0.13885673
#  0.1914649  0.21384447 0.14315952 0.19335542]
# Mean r2 score for KNR : 0.17119412151692703
# Standard Deviation in r2 score for KNR : 0.027578916544107275
#
# score for SVR : [ 0.0261732   0.02311539  0.03547496  0.00539958  0.0622689  -0.02771586
#   0.06448246  0.05298974  0.00071683  0.07166495]
# Mean r2 score for SVR : 0.03145701618183425
# Standard Deviation in r2 score for SVR : 0.030593155151467273

# %%
# Lets check Lasso Regression and find best value of alpha
lsreg=Lasso()
parameters={"alpha":[0.0001,0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
# Lets Check Max r2 score when we use Lasso
lareg=Lasso(alpha=0.01)
r_state=maxr2_score(lsreg,x,y)
# Out:
# The r2 score at r state 42 is 0.14207073597099307
# The r2 score at r state 43 is 0.15333130664330108
# The r2 score at r state 44 is 0.1125211395154575
# The r2 score at r state 45 is 0.15054513837552108
# The r2 score at r state 46 is 0.12990155374874757
# The r2 score at r state 47 is 0.12787783695310484
# The r2 score at r state 48 is 0.14440933945844192
# The r2 score at r state 49 is 0.12627791973268854
# The r2 score at r state 50 is 0.14082609940222368
# The r2 score at r state 51 is 0.10513026322026553
# The r2 score at r state 52 is 0.13197023929144136
# The r2 score at r state 53 is 0.12821310539980424
# The r2 score at r state 54 is 0.12066574787332562
# The r2 score at r state 55 is 0.11010530015690523
# The r2 score at r state 56 is 0.13159772291874583
# The r2 score at r state 57 is 0.11496200627822883
# The r2 score at r state 58 is 0.13743740654506476
# The r2 score at r state 59 is 0.1451529796514942
# The r2 score at r state 60 is 0.1286483798149909
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=200,random_state=45)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=45, verbose=0, warm_start=False)

# %%
rf.score(x_train,y_train)
# Out:
# 0.9664917732513817

# %%
pred=rf.predict(x_test)

# %%
pred
# Out:
# array([ 705.54920637,  752.72174472,  711.67262922, ...,  465.73824571,
#        1299.29460409,  448.35005883])

# %%
score=cross_val_score(rf,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.74695055 0.75642196 0.73320288 0.79492594 0.74417349]
# 0.7551349651426793
# 0.021227965371387502

# %%
# checking the model and its metrics by running a set of codes.
score=[]
cv=[]
MSE=[]
RMSE=[]
MAE=[]
    
algorithm=[LinearRegression(),SVR(C= 10, kernel= 'rbf'),DecisionTreeRegressor(),KNeighborsRegressor(n_neighbors=16)]
for i in algorithm:
    l=i
    print(l)
    l.fit(x_train,y_train)
    pred=l.predict(x_test)
    r2score=r2_score(y_test,pred)
    print("R2 score", r2score)
    score.append(r2score)
    crossscore=cross_val_score(l,x,y,cv=5,scoring='r2').mean()
    print("The CV Score is", crossscore)
    cv.append(crossscore)
    mean_sqrd_error=mean_squared_error(y_test,pred)
    MSE.append(mean_sqrd_error)
    print("Mean Squared Error is", mean_sqrd_error )
    rootMSE=np.sqrt(mean_sqrd_error)
    RMSE.append(rootMSE)
    print("Root Mean Squared Error is: ",rootMSE)
    Meanabserror=mean_absolute_error(y_test,pred)
    MAE.append(Meanabserror)
    print("Mean Absolute Error is: ", Meanabserror)
    print("\n")
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# R2 score 0.16088733343146777
# The CV Score is 0.12634956844915396
# Mean Squared Error is 184491.16662655052
# Root Mean Squared Error is:  429.5243492824947
# Mean Absolute Error is:  301.79032804035
#
#
# SVR(C=10, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# R2 score 0.04921580286889837
# The CV Score is 0.023935915560876996
# Mean Squared Error is 209043.78247099058
# Root Mean Squared Error is:  457.21306025855233
# Mean Absolute Error is:  230.38656630931868
#
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
# ...

# %%
result=pd.DataFrame({'Model':['LinearRegression','SVR','DecisionTreeRegressor','KNeighborsRegressor'],'R2score':score,'Cross_val_score':cv,'Mean Squared Error':MSE, 'Root Mean Squared Error': RMSE, 'Mean Absolute Error':MAE})
result
# Out:
#                    Model   R2score  Cross_val_score  Mean Squared Error  \
# 0       LinearRegression  0.160887         0.126350       184491.166627
# 1                    SVR  0.049216         0.023936       209043.782471
# 2  DecisionTreeRegressor  0.519615         0.524898       105619.737078
# 3    KNeighborsRegressor  0.169155         0.169349       182673.472438
#
#    Root Mean Squared Error  Mean Absolute Error
# 0               429.524349           301.790328
# 1               457.213060           230.386566
# 2               324.991903           111.206231
# 3               427.403173           297.517478

# %%
from sklearn.ensemble import AdaBoostRegressor
model=AdaBoostRegressor()
model.fit(x_train,y_train)
print(model.score(x_train,y_train))
abpred=model.predict(x_test)
print(abpred)
# Out:
# 0.6699834436282972
# [ 565.99398525  653.22429587  565.99398525 ...  565.99398525 1426.7571518
#   565.99398525]

# %%
scoreab=cross_val_score(model,x,y,cv=5)
print(scoreab)
print(scoreab.mean())
print(scoreab.std())
# Out:
# [0.60685855 0.66356916 0.66349027 0.70268412 0.61956516]
# 0.651233452417106
# 0.03441390057334734

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()

# %%
gbr.fit(x_train,y_train)
print(gbr.score(x_train,y_train))
gbrpred=gbr.predict(x_test)
print(gbrpred)
# Out:
# 0.7537304238304126
# [ 718.50202308  748.06806381  702.7544554  ...  481.20964114 1248.25407974
#   464.4323037 ]

# %%
scoregbr=cross_val_score(gbr,x,y,cv=5,scoring="r2")
print(scoregbr)
print(scoregbr.mean())
print(scoregbr.std())
# Out:
# [0.72937731 0.74277303 0.7231925  0.75621643 0.73091892]
# 0.7364956395959348
# 0.011722280446169242

# %%
# As we see that after applying so many models for testing we found that RandonForestRegressor very well for this dataset so I am going finalise the model this model
rf=RandomForestRegressor(n_estimators=200,random_state=45)
r_state=maxr2_score(rf,x,y)
# Out:
# The r2 score at r state 42 is 0.7542077452284962
# The r2 score at r state 43 is 0.7726703406061259
# The r2 score at r state 44 is 0.7517047492961211
# The r2 score at r state 45 is 0.7632986923948758
# The r2 score at r state 46 is 0.7393756297174998
# The r2 score at r state 47 is 0.7579303705218645
# The r2 score at r state 48 is 0.7554088135334328
# The r2 score at r state 49 is 0.7607200801735501
# The r2 score at r state 50 is 0.7388054060596045
# The r2 score at r state 51 is 0.7211048155467092
# The r2 score at r state 52 is 0.7588871935649384
# The r2 score at r state 53 is 0.7410306106066497
# The r2 score at r state 54 is 0.7496620238385305
# The r2 score at r state 55 is 0.7686225624503767
# The r2 score at r state 56 is 0.7495493490647385
# The r2 score at r state 57 is 0.7647011890207673
# The r2 score at r state 58 is 0.7580391720200469
# The r2 score at r state 59 is 0.7765866862969946
# The r2 score at r state 60 is 0.7484040906946766
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=71,test_size=0.20)
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

# %%
# Lets find the RMSE and R2 SCORE using sklearn.metrics
from sklearn.metrics import mean_squared_error,r2_score
print("RMSE is :",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2 score is :",r2_score(y_test,y_pred))
# Out:
# RMSE is : 213.5056994192017
# r2 score is : 0.7893245527043249

# %%
# saving The Model
from sklearn.externals import joblib
joblib.dump(rf,"Auto_Insurance_claim.pkl")
# Out:
# ['Auto_Insurance_claim.pkl']

# %%
rf_from_joblib=joblib.load("Auto_Insurance_claim.pkl")

# %%
from sklearn.model_selection import cross_val_predict
score=cross_val_predict(rf_from_joblib,x,y,cv=10)

# %%
score
# Out:
# array([ 273.17403859,  660.97237828, 1464.87432524, ..., 1404.42265906,
#         752.69300394,  271.23793177])
